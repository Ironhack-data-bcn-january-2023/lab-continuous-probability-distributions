# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
# Viz mantra
from matplotlib import pyplot as plt
# %matplotlib inline
# %config Inlinebackend.figure_format = 'retina'

from scipy.stats import uniform
import numpy as np
import seaborn as sns
import pandas as pd


import seaborn as sns
sns.set_context('poster')
sns.set(rc={'figure.figsize': (16., 9.)})
sns.set_style('whitegrid')

# %%
#The specific range of the uniform distribution is not specified, so by default it generates random numbers between 0 and 1.
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x


print(randoms)
# Out:
# [2.5675203  2.47248197 2.26098621 2.10510072 2.64343863 2.39155735
#  2.20572934 2.77453694 2.76802472 2.49195844]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here

def uni_dist(bottom, ceiling, count):
    x = uniform.rvs(size=count)
    a = bottom
    b = ceiling 
    randos = a + (b-a)*x
    return randos

# %%
set1= uni_dist(10, 15, 100)
set2= uni_dist(10, 60, 1000)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))

sns.histplot(set1, bins=10, ax=ax1)
sns.histplot(set2, bins=10, ax=ax2)

# Set the y-axis limits to be the same for both subplots
y_max = max(ax1.get_ylim()[1], ax2.get_ylim()[1])
ax1.set_ylim(0, y_max)
ax2.set_ylim(0, y_max)

# Add labels and title to each subplot
ax1.set_xlabel("Random Values")
ax1.set_ylabel("Value Counts")
ax1.set_title("Set 1 ")

ax2.set_xlabel("Random Values")
ax2.set_ylabel("Value Counts")
ax2.set_title("Set 2")

# Adjust the spacing between the subplots
fig.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# Exponential distribution predicts the probability you will wait for a certain amount of time until the next event. 
# based on an average (aka scale OR expected value).
# The average is used to describe the center of the distribution

# your code here
def exp_dist(scale, size):
    sample = np.random.exponential(scale=scale, size=size)
    
    fig = sns.histplot(sample, bins=100)
    plt.xlabel('The periocity of an event.')
    plt.ylabel('Frequency/ Count')
    return fig

# %%
exp_dist(scale=2, size=1000)
# Out:
# <AxesSubplot: xlabel='The periocity of an event.', ylabel='Frequency/ Count'>

# %%
exp_dist(scale=200, size=1000)
# Out:
# <AxesSubplot: xlabel='The periocity of an event.', ylabel='Frequency/ Count'>

# %% [markdown]
# How are the two distributions different?

# %%
# The two exponential distributions are different because they have different scale parameters, 
#which means that they have different `mean` and different `range of values`
# the first distribution will have a smaller range, centered at 2. 
#the secons distribution will have a larger range, centered at 200 -> more spreadout.

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)
from scipy.stats import expon

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
wait_bank = expon(10)
less_than_15 = wait_bank.cdf(15)
less_than_15
# Out:
# 0.9932620530009145

# %%
more_than_15 = 1 - less_than_15
more_than_15
# Out:
# 0.006737946999085476

# %%
# your result should be 👇🏾
# 1. 0.7768698398515702
# 2. 0.2231301601484298

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
from scipy.stats import norm

# %%
# your code here

norm()

def norm_dist(average, standard_deviation, x):
    sample = norm(loc=average, scale=standard_deviation)
    
    return sample.rvs(x)

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

a = norm_dist(10, 1, 1000)
b = norm_dist(10, 50, 1000)

# %%
fix, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10,5))
sns.histplot(a, bins=50, ax=ax1)
sns.histplot(b, bins=50, ax=ax2)

# Set the y-axis limits to be the same for both subplots
y_max = max(ax1.get_ylim()[1], ax2.get_ylim()[1])
ax1.set_ylim(0, y_max)
ax2.set_ylim(0, y_max)

# Add labels and title to each subplot
ax1.set_xlabel("Values")
ax1.set_ylabel("Counts")
ax1.set_title("std=1")

ax2.set_xlabel("Values")
ax2.set_ylabel("Counts")
ax2.set_title("std=50")

#mean line
ax1.axvline(x=a.mean(), color = "red", label="Average")

ax2.axvline(x=b.mean(), color = "red", label="Average")

# %%
# the 1o distribution has a std of 1. This means that the values will be tightly close together, with very little stread.
    #The distribution will be narrower and taller 
# the 2o distribution has a std of 50. This means that the values will be more spread out. 
    #The distribution will be wider and have flatter shape

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
vehicles = pd.read_csv('vehicles.csv')
vehicles.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
sns.histplot(vehicles['Fuel Barrels/Year'], bins=50)
# Out:
# <AxesSubplot: xlabel='Fuel Barrels/Year', ylabel='Count'>

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here

sns.histplot(vehicles['CO2 Emission Grams/Mile'], bins=50)
# Out:
# <AxesSubplot: xlabel='CO2 Emission Grams/Mile', ylabel='Count'>

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
sns.histplot(vehicles['Combined MPG'], bins=50)
# Out:
# <AxesSubplot: xlabel='Combined MPG', ylabel='Count'>

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
# 1. Fuel Barrels/Year
# 2. CO2 Emission Grams/Mile

    #These graphs are bell-shaped with the majority of the data clustered in the middle with a few data point at the extremes. 
    #The curve is also symmetric, that is, roughly the same number of data points on each side
