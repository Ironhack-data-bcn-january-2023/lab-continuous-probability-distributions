# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.81493737 2.20306706 2.41949311 2.91996913 2.82849471 2.41841914
#  2.21507788 2.50462395 2.7196147  2.4710746 ]

# %%
x
# Out:
# array([0.81493737, 0.20306706, 0.41949311, 0.91996913, 0.82849471,
#        0.41841914, 0.21507788, 0.50462395, 0.7196147 , 0.4710746 ])

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
def udrn(bottom, ceiling, count):
    y = uniform.rvs(size=count)
    return  bottom + (ceiling-bottom)*y

# %%
bottom=10
ceiling=15
count=100
ud1 = udrn(bottom, ceiling, count)
ud1
# Out:
# array([10.52101698, 14.37333973, 11.29895368, 13.87516021, 14.74548896,
#        10.7318447 , 10.53235407, 13.04027252, 14.77172497, 12.00413348,
#        13.99679483, 10.26552218, 14.79991503, 14.97039273, 14.62554992,
#        14.78383925, 13.44183746, 13.85982137, 12.81602663, 13.01276217,
#        14.15284913, 11.04057622, 12.10009312, 11.0029546 , 10.64671209,
#        13.98600519, 10.64864192, 11.2257002 , 12.85178686, 14.50608472,
#        12.04546301, 10.81786349, 13.41034783, 13.40310734, 12.96877188,
#        13.22271715, 12.24363693, 13.27100259, 14.72312676, 13.17688832,
#        10.4567109 , 12.9923875 , 13.31027598, 11.64717134, 13.05552964,
#        10.26965324, 11.18026354, 11.91405852, 10.21871265, 11.68412076,
#        12.58392782, 12.70598614, 11.04641068, 14.42505069, 13.20788174,
#        14.69364749, 10.94761418, 11.0024339 , 13.90921462, 14.64776843,
#        14.90908146, 12.8077822 , 13.50592021, 12.72682854, 13.30928842,
# ...

# %%
bottom=10
ceiling=60
count=1000
ud2 = udrn(bottom, ceiling, count)
ud2
# Out:
# array([28.30442828, 55.27983903, 20.52936351, 44.99283706, 15.65908331,
#        31.04915459, 13.30742751, 38.98562606, 42.72791653, 40.92199469,
#        36.76341395, 27.04981046, 11.43137339, 40.5078231 , 31.02796093,
#        16.24430632, 59.86454236, 39.46131982, 49.45495842, 16.88090659,
#        28.6760837 , 14.23693658, 21.53209563, 59.79191721, 10.84411107,
#        45.83825162, 52.37048088, 10.50971356, 59.14130705, 41.5793774 ,
#        58.72078602, 38.45938544, 20.0209212 , 20.41735659, 54.99620811,
#        28.14218984, 37.07619435, 26.37273559, 51.64960081, 59.60910674,
#        30.61878276, 10.18630997, 17.92915722, 53.29421861, 33.73233979,
#        22.97196903, 18.16406836, 12.44291173, 12.50208424, 50.23303617,
#        50.91088735, 49.71604709, 50.47768108, 59.86270058, 35.78598263,
#        15.59893881, 42.27535792, 17.91141315, 56.80573035, 10.62562174,
#        29.28614596, 25.23514839, 51.06943066, 56.48779435, 34.97894277,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

axs[0].hist(ud1, bins=10)
axs[0].set_title('Uniform Distribution 1')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Count')
axs[0].set_ylim([0, 120])

axs[1].hist(ud2, bins=10)
axs[1].set_title('Uniform Distribution 2')
axs[1].set_xlabel('Value')
axs[1].set_ylabel('Count')
axs[1].set_ylim([0, 120])

plt.show()

# %% [markdown]
# How are the two distributions different?

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 2 and 200.
#
# 1. Use the function to generate two number sequences with the size of 1000 for both.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %% [markdown]
# How are the two distributions different?

# %%
def exponential_dist(mean, size):
    return np.random.exponential(scale=mean, size=size)

# %%
first = exponential_dist(mean=2, size=1000)
first
# Out:
# array([1.72907047e-01, 7.35388899e+00, 1.11196382e+00, 2.17945848e+00,
#        1.12387370e-01, 3.48772798e-01, 9.19848182e-01, 6.57911723e-01,
#        1.80151093e+00, 2.16457486e+00, 2.53276950e+00, 1.00205575e-01,
#        9.73537913e-02, 1.24395840e-01, 7.72981457e-01, 7.53739321e-02,
#        1.80056935e-01, 9.45477210e-01, 1.47561379e-01, 2.75391194e+00,
#        3.06408735e-01, 2.96674802e+00, 6.88969838e-01, 3.08329356e+00,
#        2.22868504e+00, 2.87827790e+00, 1.58898496e+00, 6.28330704e-02,
#        1.90719226e+00, 5.11333337e+00, 5.65419168e-01, 2.59670823e+00,
#        5.19103119e-01, 3.13722491e-01, 2.02962353e+00, 2.56705397e+00,
#        7.52323751e-01, 6.76694052e-01, 2.66147499e+00, 4.17735039e-01,
#        2.81676521e+00, 1.83647320e+00, 1.73080716e-01, 4.26805896e-01,
#        6.22545816e-01, 2.17313845e-01, 7.89686296e-01, 1.34995460e+00,
#        3.60896552e-01, 6.58566036e-01, 1.94529193e+00, 1.01968391e+00,
# ...

# %%
first.mean()
# Out:
# 1.890703049016908

# %%
second = exponential_dist(mean=200, size=1000)
second
# Out:
# array([6.54761639e+01, 1.49813283e+02, 2.25837467e+02, 1.01584232e+02,
#        5.10153496e+01, 2.70631232e+02, 2.67761554e+02, 5.17971691e+02,
#        5.84827737e+00, 3.82213628e+02, 3.43477752e+02, 1.22701117e+03,
#        5.28281336e+01, 2.92784020e+00, 2.39647529e+02, 1.19624143e+02,
#        1.71995990e+01, 4.07424993e+01, 2.21018912e+02, 1.81074533e+02,
#        4.29915815e+01, 1.33078550e+01, 2.54703216e+02, 4.86479524e+00,
#        1.21152255e+02, 9.77994631e+01, 1.14189866e+01, 4.61542259e+01,
#        2.92473963e+02, 4.95046935e+02, 2.16142317e+02, 9.91653407e+01,
#        1.46640415e+02, 5.70623896e+01, 1.49338380e+01, 9.31143597e+01,
#        1.74075292e+01, 1.18699546e+02, 3.30600041e+02, 2.33728895e+02,
#        8.21822824e+01, 3.57841141e+02, 1.61099807e+02, 4.24288636e+02,
#        1.18682386e+02, 1.22979554e+02, 7.46045952e+00, 3.37749394e+02,
#        2.82668580e+02, 1.87485455e+01, 2.12844604e+02, 2.17540082e+01,
# ...

# %%
second.mean()
# Out:
# 194.53650010258337

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

axs[0].hist(first, bins=100)
axs[0].set_title('Exponential Distribution 1')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Count')
axs[0].set_ylim([0, 120])

axs[1].hist(second, bins=100)
axs[1].set_title('Exponential Distribution 2')
axs[1].set_xlabel('Value')
axs[1].set_ylabel('Count')
axs[1].set_ylim([0, 120])

plt.show()

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)

mean_time = 10
lambda_val = 1 / mean_time
time_limit = 15

def exp_cdf(x):
    return 1 - np.exp(-lambda_val * x)


prob_less_than_15 = exp_cdf(time_limit)
prob_less_than_15
# Out:
# 0.7768698398515702

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here
prob_more_than_15 = 1 - prob_less_than_15
prob_more_than_15
# Out:
# 0.2231301601484298

# %%
# your result should be 👇🏾
# 1. 0.7768698398515702
# 2. 0.2231301601484298

# %%
# your answer below

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
from scipy.stats import norm

# %%
def norm_generator(mean, std_dev, count):
    return np.random.normal(mean, std_dev, count)

# %%
mean1, std_dev1, count1 = 10, 1, 1000
norm1 = norm_generator(mean1, std_dev1, count1)
norm1
# Out:
# array([10.32686876,  9.51232512,  9.68752715, 10.74007729, 11.21910884,
#         9.99863124,  9.71983844, 11.49449326,  9.87718234,  9.31581631,
#         9.37586101,  9.71080642, 11.20049817,  9.30062864, 10.10324736,
#         9.46167561, 10.22753822, 11.30456749, 10.75047545, 12.13905466,
#        10.82964217, 11.52064213,  9.65914847,  9.0110893 ,  9.38912837,
#        11.37622055, 10.14870768,  7.96856342,  9.99212688, 10.00015876,
#         9.68700033, 11.26284822,  8.92527436,  9.68606647,  9.51928161,
#        10.31197882, 10.00230324, 10.70362611, 10.09883656, 10.95560887,
#         9.46793284,  9.74874994,  8.18560288,  9.30200264,  9.16729958,
#        10.31589248, 10.77492835,  9.82030504, 10.80312161,  9.17988283,
#         8.94853955, 10.84879166, 10.49543768,  9.37558836, 11.39083078,
#        10.49389615, 11.72644151, 10.95194547, 10.03844916,  9.17546137,
#         9.93071158, 10.68269422, 10.02959065,  9.51082997,  9.06177158,
# ...

# %%
mean2, std_dev2, count2 = 10, 50, 1000
norm2 = norm_generator(mean2, std_dev2, count2)
norm2
# Out:
# array([ 8.49332338e+01, -3.69253018e+01, -5.57596988e+01,  9.64651989e+01,
#         6.49310291e+01, -7.91745007e+01, -3.65567585e+01, -6.21064924e+00,
#        -5.35491209e+01,  7.48079508e+01,  2.26572820e+01,  5.97252069e+01,
#         2.97988509e+01,  1.49534538e+01, -2.11970148e+01, -5.40964154e+01,
#        -5.99978192e+01,  2.67291602e+01,  1.25735924e+01,  6.62600447e+01,
#         7.59530026e+01, -4.92670867e+01,  1.12560365e+02,  1.13388319e+01,
#        -5.70015824e+01, -6.38384535e+01,  2.50600864e+01,  3.73689930e+01,
#         7.53558044e+01,  1.95178443e+01, -4.11479735e+00, -4.01686294e+01,
#         2.59149564e+01,  7.20904156e+01, -2.28497754e+01, -7.61480658e+00,
#         8.20222626e-01,  3.53801200e+01, -8.43568637e+01, -2.58779470e+01,
#        -3.90863821e+01,  3.52518085e+01, -1.84591710e+01, -8.80137015e+00,
#         4.29055384e+01,  5.16614352e+01,  8.90755053e+00, -3.59938927e+01,
# ...

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

axs[0].hist(norm1, bins=100)
axs[0].set_title('Normal Distribution 1')
axs[0].set_xlabel('Value')
axs[0].set_ylabel('Count')

axs[1].hist(norm2, bins=100)
axs[1].set_title('Normal Distribution 2')
axs[1].set_xlabel('Value')
axs[1].set_ylabel('Count')

plt.show()

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below 
'''
both have the same mean but Norm2 has a much larger standard deviation'''

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
import pandas as pd
vehicles_df = pd.read_csv('vehicles.csv')

# %%
vehicles_df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
vehicles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %%
vehicles_df.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %%
plt.hist(vehicles_df['Fuel Barrels/Year'], bins=50)
plt.xlabel('Fuel Barrels/Year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
plt.hist(vehicles_df['CO2 Emission Grams/Mile'], bins=50)
plt.xlabel('CO2 Emission Grams/Mile')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 3. Combined MPG

# %%
plt.hist(vehicles_df['Combined MPG'], bins=50)
plt.xlabel('Combined MPG')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
#None of them really appear normally distributed, they all have skews
